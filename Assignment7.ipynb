# %% [markdown]
# # Question#1

# %%
def add_numbers(num1, num2):
    return num1 + num2
result = add_numbers(10, 15)
print("The sum is:", result)

# %% [markdown]
# # Question#2

# %%
def currency_converter(amount, exchange_rate):
    converted_amount = amount * exchange_rate
    return f"{amount} USD is equivalent to {converted_amount} PKR"
currency_converter(100,280)

# %% [markdown]
# # Question#3

# %%
def display_student_info(name,age,grade,school):
    return f"""Name:{name}
Age:{age}
Grade:{grade}
School:{school}"""
print(display_student_info("John Doe",15,"10th","Greenwood High"))

# %% [markdown]
# # Question#4

# %%
def calculate_price(price,quantity):
    total_price=price*quantity
    return f"Total_price:{total_price}"
print(calculate_price(1000,3))

# %% [markdown]
# # Question#5

# %%
def calculate_rectangle(length, width):
    def calculate_area():
        return length*width
    def calcukate_perimeter():
        return 2*(length + width)
    return calculate_area(), calcukate_perimeter()
area, perimeter = calculate_rectangle(5, 3)
print("Area:", area)
print("Perimeter:", perimeter)

# %% [markdown]
# # Question#6

# %%
numbers = [1, 3, 5, 7, 9, 10, 12, 15, 18, 20, 21, 25, 30]
result = [num for num in numbers if num % 3 == 0 or num % 5 == 0]
print("Original List:", numbers)
print("Numbers divisible by 3 or 5:", result)

# %% [markdown]
# # Question#7

# %%
balance = 1000
try:
    amount = float(input("Enter amount to withdraw: "))
    if amount <= 0:
        print("Amount must be more than zero.")
    elif amount > balance:
        print("Insufficient balance.")
    else:
        balance -= amount
        print("Withdrawal successful.")
        print("Remaining balance:", balance)
except ValueError:
    print("Please enter a valid number.")
finally:
    print("Thank you for using the ATM.")

# %% [markdown]
# # Question#8

# %%
available_seats = 5
try:
    tickets = int(input("How many tickets do you want to book? "))
    if tickets <= 0:
        print("You must book at least 1 ticket.")
    elif tickets > available_seats:
        print("Not enough seats available.")
    else:
        print(f"{tickets} ticket(s) booked successfully.")
except ValueError:
    print("Please enter a valid number.")
finally:
    print("Thank you for booking with us.")

# %% [markdown]
# # Question#9

# %%
class Light:
    def turn_on(self):
        print("The light is now ON.")
    def check_status(self):
        print("The light is bright and working.")
light = Light()
light.turn_on()
light.check_status()

# %% [markdown]
# # Question#10

# %%
class Student:
    def __init__(self, name, grade, age):
        self.name = name
        self.grade = grade
        self.age = age
    def introduce(self):
        print(f"My name is {self.name}, I am {self.age} years old.")
    def show_grade(self):
        print(f"My grade is {self.grade}.")
student = Student("Alice", "A", 16)
student.introduce()
student.show_grade()
