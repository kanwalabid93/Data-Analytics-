# %% [markdown]
# #Question:1

# %%
a=15
b=4
a+b
# Out:
# 19

# %%
a-b
# Out:
# 11

# %%
a*b
# Out:
# 60

# %%
a/b
# Out:
# 3.75

# %%
a//b
# Out:
# 3

# %%
a%b
# Out:
# 3

# %% [markdown]
# #Question:2

# %%
Food="Daal Chawal"

# %%
Food
# Out:
# 'Daal Chawal'

# %% [markdown]
# #Question:3

# %%
apples="22"
mangoes=33
apples=int(apples)
total=apples + mangoes

# %%
total
# Out:
# 55

# %% [markdown]
# #Question:4

# %%
num1 = 10
num2 = 5.6
num3 = 4.43
num4='23'

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 10.0

# %%
type(5.6)
# Out:
# float

# %%
type(num2)
# Out:
# float

# %%
int(num2)
# Out:
# 5

# %%
type(num3)
# Out:
# float

# %%
str(num3)
# Out:
# '4.43'

# %%
type(num4)
# Out:
# str

# %%
int(num4)
# Out:
# 23

# %% [markdown]
# #Question:5

# %%
name="Kanwal Abid"
age=29
a=1
final_age=age + a

# %%
final_age
# Out:
# 30

# %% [markdown]
# #Question:6

# %%
a = 2
b = 1
c = 6
d = 3

# %%
a+b
# Out:
# 3

# %%
c-a
# Out:
# 4

# %%
d*b
# Out:
# 3

# %%
c//d
# Out:
# 2

# %%
c%d
# Out:
# 0

# %%
(d+a)**2
# Out:
# 25

# %% [markdown]
# #Question:7

# %%
age=20
age= age + 5

# %%
age
# Out:
# 25

# %% [markdown]
# #Question:8

# %%
a = '2'
b = '11'
c = 6.3

# %%
int(a)+c
# Out:
# 8.3

# %%
float(b)*c
# Out:
# 69.3

# %%
int(c)+c
# Out:
# 12.3

# %% [markdown]
# #Question:9

# %%
books=12
books=books-4

# %%
books
# Out:
# 8

# %% [markdown]
# #Question:10

# %%
cookies=5
cookies=cookies*3

# %%
cookies
# Out:
# 15

# %% [markdown]
# #Question:11

# %%
20 - 4 * (3 + 2) + 18 / 3
# Out:
# 6.0
