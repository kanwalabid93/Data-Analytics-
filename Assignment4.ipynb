# %% [markdown]
# # Question:1

# %%
products = {
    101: {"name": "Laptop", "category": "Electronics", "price": 1200, "stock": 50}, 
    102: {"name": "Shirt", "category": "Apparel", "price": 25, "stock": 200}, 
    103: {"name": "Coffee Maker", "category": "Home Appliances", "price": 80, "stock": 30} 
}
products.update({102:{"stock":250}})
products.update({104: {'name': 'Smartphone', 'category': 'Electronics', 'price': 800, 'stock': 100}})
products
# Out:
# {101: {'name': 'Laptop',
#   'category': 'Electronics',
#   'price': 1200,
#   'stock': 50},
#  102: {'stock': 250},
#  103: {'name': 'Coffee Maker',
#   'category': 'Home Appliances',
#   'price': 80,
#   'stock': 30},
#  104: {'name': 'Smartphone',
#   'category': 'Electronics',
#   'price': 800,
#   'stock': 100}}

# %% [markdown]
# # Question:2

# %%
employee = ("Ali", 25, "Data Analyst", 75000)
Name, Age, Profession, Salary=employee
updated_Salary=Salary*0.1+Salary
updated_Salary
# Out:
# 82500.0

# %% [markdown]
# # Question:3

# %%
shopping_list = ["apple", "banana", "apple", "orange", "banana", "grape"]
shopping_list=list(set(shopping_list))
shopping_list
# Out:
# ['orange', 'grape', 'apple', 'banana']

# %% [markdown]
# # Question:4

# %%
course_a = {"John", "Alice", "Bob", "David"}
course_b = {"Alice", "Eve", "Charlie", "David"}
print("Students in Course A but not in Course B:",course_a.difference(course_b))
print("Students only in one of the two courses:",course_a.symmetric_difference(course_b))
# Out:
# Students in Course A but not in Course B: {'Bob', 'John'}
# Students only in one of the two courses: {'John', 'Bob', 'Charlie', 'Eve'}

# %% [markdown]
# # Question:5

# %%
numbers = (10, 20, 30, 40, 50, 60, 70)
print(numbers[:3])
print(numbers[4:])
print(numbers[0:7:2])
# Out:
# (10, 20, 30)
# (50, 60, 70)
# (10, 30, 50, 70)

# %% [markdown]
# # Question:6

# %%
student_details = { 
    "Ali": {"age": 20, "grade": "A", "city": "Karachi"}, 
    "Sara": {"age": 21, "grade": "B", "city": "Lahore"}, 
    "Omar": {"age": 19, "grade": "A", "city": "Islamabad"}, 
    "Hina": {"age": 22, "grade": "C", "city": "Faisalabad"}
}
student_details.update({"Zara": {"age": 20, "grade": "B", "city": "Multan"}})

# %%
student_details
# Out:
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'},
#  'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'},
#  'Omar': {'age': 19, 'grade': 'A', 'city': 'Islamabad'},
#  'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'},
#  'Zara': {'age': 20, 'grade': 'B', 'city': 'Multan'}}

# %% [markdown]
# # Question:7

# %%
inventory = {
    "The Great Gatsby": {"price": 10.99,"quantity": 5}, 
    "Rich dad poor dad": {"price":8.99,"quantity": 8},
    "Harry Potter": {"price": 12.50,"quantity": 2}
}
inventory.update({"Atomic Habits": {"price": 15.99, "quantity": 4}})
print("inventory=",inventory)
print(inventory.keys())
inventory.pop("Rich dad poor dad")
inventory
# Out:
# inventory= {'The Great Gatsby': {'price': 10.99, 'quantity': 5}, 'Rich dad poor dad': {'price': 8.99, 'quantity': 8}, 'Harry Potter': {'price': 12.5, 'quantity': 2}, 'Atomic Habits': {'price': 15.99, 'quantity': 4}}
# dict_keys(['The Great Gatsby', 'Rich dad poor dad', 'Harry Potter', 'Atomic Habits'])
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5},
#  'Harry Potter': {'price': 12.5, 'quantity': 2},
#  'Atomic Habits': {'price': 15.99, 'quantity': 4}}

# %% [markdown]
# # Question:8

# %%
d = {"x": 1, "y": 2}
d.items()
# Out:
# dict_items([('x', 1), ('y', 2)])

# %% [markdown]
# # Question:9

# %%
A = {"Ali", "Sara"}
B = {"Ahmed", "Zara"}
A.union(B)
# Out:
# {'Ahmed', 'Ali', 'Sara', 'Zara'}

# %% [markdown]
# # Question:10

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7}
print("common elements:",A.intersection(B))
print("elements only in Set A:",A.difference(B))
print("elements only in Set B:",B.difference(A))
# Out:
# common elements: {4, 5}
# elements only in Set A: {1, 2, 3}
# elements only in Set B: {6, 7}
