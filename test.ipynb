# %%
score = 0
print("\nQ1. What is the capital of Pakistan?")
print("A. Lahore")
print("B. Islamabad")
print("C. Karachi")
print("D. Quetta")
answer = input("Enter your answer: ")
if answer == "B":
    print("Correct!")
    score = score + 1
else:
    print("Wrong!")
print("\nQ2. Who is the founder of Pakistan?")
print("A. Quaid-e-Azam")
print("B. Imran Khan")
print("C. Ali Mughal")
print("D. Naseem Shah")
answer = input("Enter your answer: ")
if answer == "A":
    print("Correct!")
    score = score + 1
else:
    print("Wrong!")
print("\nQ3.Is 2+2=4?")
print("A. Yes")
print("B. NO")
print("C. Both A and B")
print("D. None of these")
answer = input("Enter your answer: ")
if answer == "A":
    print("Correct!")
    score = score + 1
else:
    print("Wrong!")
print("\nQ4.which fruit is the king of all fruits?")
print("A. Gavava")
print("B. Grapes")
print("C. Banana")
print("D. Mango")
answer = input("Enter your answer: ")
if answer == "B":
    print("Correct!")
    score = score + 1
else:
    print("Wrong!")
print("\nQ5. when was pakistan established?")
print("A. 04 August")
print("B. 15 August")
print("C. 6 September")
print("D. None of these")
answer = input("Enter your answer: ")
if answer == "D":
    print("Correct!")
    score = score + 1
else:
    print("Wrong!")
print("\nQuiz Finished!")
print("You got", score, "out of 5 correct!")
if score == 5:
    print("Excellent!")
elif score >= 3:
    print("Good Job!")
else:
    print("Try Again!")
# Out:
# Q1. What is the capital of Pakistan?
# A. Lahore
# B. Islamabad
# C. Karachi
# D. Quetta
