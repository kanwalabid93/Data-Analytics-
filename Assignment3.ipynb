# %% [markdown]
# Question:1

# %%
nums=[1,2,3]

# %%
nums.append(10)

# %%
nums
# Out:
# [1, 2, 3, 10]

# %% [markdown]
# Question:2

# %%
order = ["burger", "fries", "coke"]

# %%
order.append("icecream")

# %%
order
# Out:
# ['burger', 'fries', 'coke', 'icecream']

# %%
order.insert(2,"biryani")

# %%
order
# Out:
# ['burger', 'fries', 'biryani', 'coke', 'icecream']

# %%
order.remove("biryani")

# %%
order
# Out:
# ['burger', 'fries', 'coke', 'icecream']

# %% [markdown]
# Question:3

# %%
nums = [4, 1, 3, 2]

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Question:4

# %%
passengers = ["Ali", "Zara", "Ahmed"]

# %%
passengers.insert(1,"Sara")

# %%
passengers
# Out:
# ['Ali', 'Sara', 'Zara', 'Ahmed']

# %%
passengers.remove("Zara")

# %%
passengers
# Out:
# ['Ali', 'Sara', 'Ahmed']

# %% [markdown]
# Question:5

# %%
text = 'hello python world'

# %%
modified_text =text.replace(" ", "_")

# %%
print(modified_text)
# Out:
# hello_python_world

# %%
split_text = modified_text.split("_")

# %%
print(split_text)
# Out:
# ['hello', 'python', 'world']

# %%
join_text= "-".join(split_text)

# %%
print(join_text)
# Out:
# hello-python-world

# %% [markdown]
# Question:6

# %%
word = "Javascript"

# %%
len(word)>5
# Out:
# True

# %% [markdown]
# Question:7

# %%
product_code="SKU-12345-XYZ"

# %%
product_code.find("-")
# Out:
# 3

# %%
product_code.count("-")
# Out:
# 2

# %%
product_code.removeprefix("SKU-",)
# Out:
# '12345-XYZ'

# %%
product_code.removesuffix("-XYZ",)
# Out:
# 'SKU-12345'

# %% [markdown]
# Question:8

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Quetta"]

# %%
cities.reverse()

# %%
cities
# Out:
# ['Quetta', 'Islamabad', 'Lahore', 'Karachi']

# %% [markdown]
# Question:9

# %%
text = "    Data Analysis with Python is very powerful    "

# %%
text.strip()
# Out:
# 'Data Analysis with Python is very powerful'

# %%
text.title()
# Out:
# '    Data Analysis With Python Is Very Powerful    '

# %%
text.replace("Pqwerful","Important")
# Out:
# '    Data Analysis with Python is very powerful    '

# %%
text.index("Python")
# Out:
# 23

# %% [markdown]
# Question:10

# %%
data = [12, 45, 2, 67, 34, 89, 23, 90]

# %%
data.sort()

# %%
data
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]

# %%
new=data.pop()

# %%
new
# Out:
# 90

# %%
data.insert(3,50)

# %%
data
# Out:
# [2, 12, 23, 50, 34, 45, 67, 89]

# %%
data.reverse()

# %%
data
# Out:
# [89, 67, 45, 34, 50, 23, 12, 2]
